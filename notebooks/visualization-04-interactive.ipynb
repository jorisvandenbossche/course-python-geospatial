# %% [markdown]
# <p><font size="6"><b>Interactive or web-based visualization</b></font></p>
#
#
# > *DS Python for GIS and Geoscience*
# > *September, 2024*
# >
# > *© 2024, Joris Van den Bossche and Stijn Van Hoey. Licensed under [CC BY 4.0 Creative Commons](https://creativecommons.org/licenses/by/4.0/)*
#
# ---

# %% [markdown]
# In the course, we used the Matplotlib library for all visualizations. This is the library that is most widely used and integrated into the other packages (e.g. the plotting functionality of pandas, geopandas, xarray, rasterio, etc all use matplotlib), and is still the "go to" library for making high-quality, publication graphics.
#
# There are, however, a bunch of alternatives to matplotlib, mainly focusing on providing more interactivity and based on web (javascript) tools. To many such packages exist to cover in this course, but we list here a few that can handle (to some extent) geospatial data:
#
# - Bokeh: https://bokeh.pydata.org/en/latest/docs/gallery/texas.html
# - GeoViews (other interface to Bokeh/matplotlib): http://geo.holoviews.org
# - Altair: https://altair-viz.github.io/gallery/index.html#maps
# - Plotly: https://plot.ly/python/#maps
# - ...
#
#
# Altair and Plotly are mostly useful for vector data. Using bokeh through holoviews with raster data is shown below.

# %%
# %matplotlib inline

import pandas as pd
import geopandas

import matplotlib.pyplot as plt

# %%
countries = geopandas.read_file("data/ne_110m_admin_0_countries.zip")
countries = countries[(countries['pop_est'] >0 ) & (countries['name'] != "Antarctica")]
countries['gdp_per_cap'] = countries['gdp_md_est'] / countries['pop_est'] * 100
cities = geopandas.read_file("data/ne_110m_populated_places.zip")
rivers = geopandas.read_file("data/ne_50m_rivers_lake_centerlines.zip")

# %% [markdown]
# ## Vector data with Leaflet

# %% [markdown]
# Another popular javascript library for online maps is [Leaflet.js](https://leafletjs.com/), and this has python bindings in the [folium](https://github.com/python-visualization/folium) and [ipyleaflet](https://github.com/jupyter-widgets/ipyleaflet) packages.

# %% [markdown]
# An example with ipyleaflet:

# %%
import ipyleaflet

# %%
m = ipyleaflet.Map(center=[48.8566, 2.3429], zoom=6)

layer = ipyleaflet.GeoJSON(data=cities.__geo_interface__)
m.add_layer(layer)
m
# Out:
# Map(center=[48.8566, 2.3429], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
m = ipyleaflet.Map(center=[48.8566, 2.3429], zoom=3)
geo_data = ipyleaflet.GeoData(
    geo_dataframe = countries,
    style={'color': 'black', 'fillColor': '#3366cc', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
    hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
    name = 'Countries')
m.add_layer(geo_data)
m
# Out:
# Map(center=[48.8566, 2.3429], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %% [markdown]
# More: https://ipyleaflet.readthedocs.io/en/latest/api_reference/geodata.html

# %% [markdown]
# An example with folium:

# %%
import folium

# %%
m = folium.Map([48.8566, 2.3429], zoom_start=6, tiles="OpenStreetMap")
folium.GeoJson(countries).add_to(m)
folium.GeoJson(cities).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79a4c904279f8c92d205581f6b2fe6f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79a4c904279f8c92d205581f6b2fe6f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79a4c904279f8c92d205581f6b2fe6f3 = L.map(
#                 &quot;map_79a4c904279f8c92d205581f6b2fe6f3&quot;,
#                 {
#                     center: [48.8566, 2.3429],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5c805b84ce32575712b6c30137d36c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d5c805b84ce32575712b6c30137d36c5.addTo(map_79a4c904279f8c92d205581f6b2fe6f3);
#
#
#
#         function geo_json_c08b5c68346c71bf71190209684534e0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c08b5c68346c71bf71190209684534e0 = L.geoJson(null, {
#                 onEachFeature: geo_json_c08b5c68346c71bf71190209684534e0_onEachFeature,
#
#         });
#
#         function geo_json_c08b5c68346c71bf71190209684534e0_add (data) {
#             geo_json_c08b5c68346c71bf71190209684534e0
#                 .addData(data);
#         }
#             geo_json_c08b5c68346c71bf71190209684534e0_add({&quot;bbox&quot;: [-179.99999999999997, -55.61182999999995, 180.00000000000003, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [60.52842980331158, 29.31857249604431, 75.15802778514092, 38.486281643216415], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817091725744, 35.650072333309225], [62.230651483005886, 35.270663967422294], [62.98466230657661, 35.40404083916762], [63.19353844590035, 35.857165635718914], [63.98289594915871, 36.0079574651466], [64.5464791197339, 36.31207326918427], [64.7461051776774, 37.111817735333304], [65.58894778835784, 37.30521678318564], [65.74563073106683, 37.66116404881207], [66.21738488145934, 37.39379018813392], [66.51860680528867, 37.36278432875879], [67.07578209825962, 37.35614390720929], [67.82999962755952, 37.144994004864685], [68.13556237170138, 37.02311513930431], [68.85944583524594, 37.344335842430596], [69.19627282092438, 37.15114350030743], [69.51878543485796, 37.60899669041342], [70.11657840361033, 37.58822276463209], [70.27057417184014, 37.735164699854025], [70.3763041523093, 38.13839590102752], [70.80682050973289, 38.486281643216415], [71.34813113799026, 38.25890534113216], [71.23940392444817, 37.953265082341886], [71.54191775908478, 37.905774441065645], [71.44869347523024, 37.06564484308052], [71.8446382994506, 36.73817129164692], [72.1930408059624, 36.948287665345674], [72.63688968291729, 37.047558091778356], [73.26005577992501, 37.495256862939], [73.9486959166465, 37.4215662704908], [74.98000247589542, 37.419990139305895], [75.15802778514092, 37.13303091078912], [74.57589277537298, 37.02084137628346], [74.06755171091783, 36.83617564548845], [72.92002485544447, 36.72000702569632], [71.84629194528392, 36.50994232842986], [71.26234826038575, 36.074387518857804], [71.49876793812109, 35.650563259416], [71.61307620635071, 35.153203436822864], [71.11501875192164, 34.733125718722235], [71.15677330921346, 34.34891144463215], [70.8818030129884, 33.98885590263852], [69.9305432473596, 34.02012014417511], [70.3235941913716, 33.35853261975839], [69.68714725126486, 33.105498969041236], [69.26252200712256, 32.5019440780883], [69.31776411324256, 31.901412258424443], [68.92667687365767, 31.620189113892067], [68.55693200060932, 31.713310044882018], [67.79268924344478, 31.58293040620963], [67.68339358914747, 31.30315420178142], [66.93889122911847, 31.304911200479353], [66.38145755398602, 30.738899237586452], [66.34647260932442, 29.887943427036177], [65.0468620136161, 29.472180691031905], [64.35041873561852, 29.560030625928093], [64.14800215033125, 29.340819200145972], [63.55026085801117, 29.468330796826166], [62.54985680527278, 29.31857249604431], [60.87424848820879, 29.829238999952608], [61.781221551363444, 30.735850328081238], [61.69931440618083, 31.379506130492672], [60.94194461451113, 31.548074652628753], [60.863654819588966, 32.18291962333443], [60.536077915290775, 32.98126882581157], [60.963700392506006, 33.52883230237626], [60.52842980331158, 33.676446031218006], [60.80319339380745, 34.40410187431986], [61.210817091725744, 35.650072333309225]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;continent&quot;: &quot;Asia&quot;, &quot;gdp_md_est&quot;: 64080.0, &quot;gdp_per_cap&quot;: 0.18778125979950483, &quot;iso_a3&quot;: &quot;AFG&quot;, &quot;name&quot;: &quot;Afghanistan&quot;, &quot;pop_est&quot;: 34124811.0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [11.64009606288164, -17.930636488519696, 24.079905226342845, -4.438023369976136], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[23.904153680118

# %%
m = folium.Map([0, 0], zoom_start=1)
folium.Choropleth(geo_data=countries, data=countries, columns=['iso_a3', 'gdp_per_cap'],
             key_on='feature.properties.iso_a3', fill_color='BuGn', highlight=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48276119a04e3eb774ad2a3baa07e027 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48276119a04e3eb774ad2a3baa07e027&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48276119a04e3eb774ad2a3baa07e027 = L.map(
#                 &quot;map_48276119a04e3eb774ad2a3baa07e027&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93275e769388809d3689d5100bfb41c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_93275e769388809d3689d5100bfb41c2.addTo(map_48276119a04e3eb774ad2a3baa07e027);
#
#
#             var choropleth_27a09d00d843a46d193df22ef4904aa1 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_f5fa5b15f440cbc29b1979e1388c62ec_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;42&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;51&quot;: case &quot;53&quot;: case &quot;56&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;90&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;112&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;119&quot;: case &quot;122&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;126&quot;: case &quot;129&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;134&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;139&quot;: case &quot;140&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;148&quot;: case &quot;152&quot;: case &quot;153&quot;: case &quot;154&quot;: case &quot;155&quot;: case &quot;156&quot;: case &quot;157&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;164&quot;: case &quot;165&quot;: case &quot;166&quot;: case &quot;167&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;174&quot;: case &quot;175&quot;: case &quot;176&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;89&quot;: case &quot;97&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2ca25f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;28&quot;: case &quot;41&quot;: case &quot;74&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;121&quot;: case &quot;138&quot;: case &quot;151&quot;: case &quot;168&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#99d8c9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;23&quot;: case &quot;54&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#66c2a4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1}

# %% [markdown]
# <div class="alert alert-info" style="font-size:120%">
#
# **NOTE**: <br>
#
# Making a quick interactive plot is also available as the `.explore()` method on a GeoDataFrame or GeoSeries, using the Folium package. See the [visualization-04-interactive notebook](./visualization-04-interactive.ipynb) for more information on interactive plotting packages or check the [GeoPandas documentation](https://geopandas.org/en/stable/docs/user_guide/interactive_mapping.html) for more examples.
#
# </div>

# %% [markdown]
# ## Using Holoviews for raster data with xarray

# %% [markdown]
# The Holoviews project (http://holoviews.org/) is a set of packages built on top of Bokeh, and which integrate with many of the other packages (pandas, GeoPandas, xarray) through the `hvplot` package (https://hvplot.holoviz.org/) and [GeoViews](https://geoviews.org/).
#
# Using the Gent example Sentinel data to showcase hvplot integration with xarray:

# %%
import xarray as xr

import hvplot.xarray
import cartopy.crs as ccrs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 3
#       1 import xarray as xr
# ----> 3 import hvplot.xarray
#       4 import cartopy.crs as ccrs
#
# File ~/.pyenv/versions/miniconda3-latest/envs/DS-geospatial/lib/python3.12/site-packages/hvplot/__init__.py:66
#      63 import sys
#      64 import textwrap
# ---> 66 import panel as _pn
#      67 import holoviews as _hv
#      69 from holoviews import Store, render  # noqa
#
# File ~/.pyenv/versions/miniconda3-latest/envs/DS-geospatial/lib/python3.12/site-packages/panel/__init__.py:48
#       1 """
#       2 Panel is a high level app and dashboarding framework
#       3 ====================================================
#    (...)
#      46 https://panel.holoviz.org/getting_started/index.html
#      47 """
# ---> 48 from param import rx
#      50 from . import layout  # noqa
#      51 from . import links  # noqa
#
# ImportError: cannot import name 'rx' from 'param' (/home/stijnvh/.pyenv/versions/miniconda3-latest/envs/DS-geospatial/lib/python3.12/site-packages/param/__init__.py)

# %%
gent = xr.open_dataarray("./data/gent/raster/2020-09-17_Sentinel_2_L1C_B0408.tiff", engine="rasterio", mask_and_scale=False)
gent = gent.assign_coords(band=("band", ["b4", "b8"]))

# %% [markdown]
# Using the default xarray Matplotlib integration with the `.plot.imshow` method:

# %%
gent.sel(band="b4").plot.imshow(robust=True, cmap="summer")

# %% [markdown]
# The equivalent method in hvplot is `.hvplot.image` (and linking the coordinate names):

# %%
gent.sel(band="b4").hvplot.image(x="x", y="y", cmap="summer", 
                                 clim=(0.05, 0.2))  # 'robust' option is not available

# %% [markdown]
# hvplot/geoviews translates multiple dimensions (in this case the bands) automatically in a drop-down menu:

# %%
gent.hvplot.image(x="x", y="y", cmap="summer", # groupby="band" # adding groupby makes this explicit instead of 'automagically'
                  clim=(0.05, 0.2))  # 'robust' option is not available

# %% [markdown]
# Similar to matplotlib plots using cartopy (see notebook `visualization-03-cartopy.ipynb`), the CRS information can be used.
#
# From https://hvplot.holoviz.org/user_guide/Geographic_Data.html#declaring-an-output-projection:
#
# > The `crs=` argument specifies the input projection, i.e. it declares how to interpret the incoming data values. You can independently choose any output projection, i.e. how you want to map the data points onto the screen for display, using the `projection=` argument.

# %%
gent.rio._crs = False  # small bug in hvplot's handling of rioxarray crs
gent.hvplot.image(x="x", y="y", cmap="summer", 
                  frame_height=400, 
                  crs=ccrs.epsg(3857),
                  projection=ccrs.UTM(zone=31), 
                  project=True, geo=True,
                  clim=(0.05, 0.2))

# %% [markdown]
# From https://hvplot.holoviz.org/user_guide/Geographic_Data.html#declaring-an-output-projection:
#
# > Note that when displaying raster data in a projection other than the one in which the data is stored, it is more accurate to render it as a quadmesh rather than an image. As you can see above, a QuadMesh will project each original bin or pixel into the correct non-rectangular shape determined by the projection, accurately showing the geographic extent covered by each sample. An Image, on the other hand, will always be rectangularly aligned in the 2D plane, which requires warping and resampling the data in a way that allows efficient display but loses accuracy at the pixel level. Unfortunately, rendering a large QuadMesh using Bokeh can be very slow

# %%
gent.hvplot.quadmesh(x="x", y="y", cmap="summer", 
                     frame_height=400, 
                     crs=ccrs.epsg(3857), 
                     projection=ccrs.UTM(zone=31), 
                     project=True, geo=True,
                     clim=(0.05, 0.2))

# %% [markdown]
# See https://hvplot.holoviz.org/user_guide/Geographic_Data.html#declaring-an-output-projection for more options.
